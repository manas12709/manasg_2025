# %% [raw]
# ---
# layout: post
# title: Student Panel Blog
# description: Blog for Student Panel
# permalink: /extacredit/
# comments: true
# ---

# %% [markdown]
# <style>
#     body {
#         background-color: #000000 !important;
#         color: #ffffff !important;
#         font-family: 'Courier New', Courier, monospace !important;
#         line-height: 1.8 !important;
#         margin: 0 !important;
#         padding: 20px !important;
#     }
#
#     article {
#         background: linear-gradient(145deg, #1e1e2f, #000000) !important;
#         border: 4px solid #4a90e2 !important;
#         padding: 25px !important;
#         border-radius: 20px !important;
#         box-shadow: 0 10px 20px rgba(0, 0, 0, 0.8) !important;
#     }
#
#     article h1 {
#         text-align: center !important;
#         font-size: 2.5em !important;
#         color: #4a90e2 !important;
#         text-shadow: 2px 2px 5px #000000 !important;
#     }
#
#     article ul {
#         list-style-type: disc !important;
#         margin: 15px 20px !important;
#         padding-left: 40px !important;
#     }
#
#     article li {
#         background-color: #2a2a40 !important;
#         padding: 10px 15px !important;
#         margin: 10px 0 !important;
#         border-radius: 10px !important;
#         border-left: 5px solid #4a90e2 !important;
#         box-shadow: 0px 5px 10px rgba(74, 144, 226, 0.5) !important;
#         color: #ffffff !important;
#     }
#
#     article code {
#         display: block !important;
#         background-color: #4a90e2 !important;
#         color: #000000 !important;
#         padding: 10px !important;
#         margin: 15px 0 !important;
#         border-radius: 8px !important;
#         font-size: 1.2em !important;
#     }
#
#     article blockquote {
#         font-style: italic !important;
#         border-left: 5px solid #4a90e2 !important;
#         margin: 20px 0 !important;
#         padding-left: 20px !important;
#         color: #d3d3d3 !important;
#     }
# </style>
#
# <article>
#     <h1>Reflection on the student panel</h1>
#     <p>
#         College interview advice for computer science and engineering majors emphasizes the importance of technical understanding, project-based learning, and effective communication. David Vasilev from Purdue highlights the value of thoroughly understanding your code for live reviews, using flowcharts for project planning, and maintaining clear documentation like GitBooks. He also advises leveraging career fairs, internships (even unrelated to your major), and networking through LinkedIn or campus events. Michael Hayes from SDSU stresses outlining your work, summarizing ideas clearly, and using use-case diagrams to communicate effectively. Vivian Ni from Columbia suggests creating portfolios on GitHub or personal websites to showcase projects and using repositories for group collaboration. She also emphasizes gaining skills from extracurriculars, such as using Arduino and laser cutters. Edwin Abraham from Purdue recommends focusing on your major’s strengths, joining clubs aligned with your passions, and applying strategies like agile methodology for better collaboration. Across the board, the advice underscores preparation, communication, and leveraging both academic and extracurricular opportunities to stand out.
#     </p>
#     <h1>My key takeaways from listening to the college students</h1>
#     <ul>
#         <li>Always listen to Mr.Mort, he's doing it for our good with practial ways, they may be hard but you will definately be ahead of a lot of people</li>
#         <li>Always read his notes, and instructions for an assignment or a code feature the answer is in the notes and comments that he writes</li>
#         <li> Structured Planning for Success.</li>
#         <li>Mastering Fundamentals.</li>
#         <li>Building and Showcasing Portfolios.</li>
#         <li>Networking and Communication</li>
#         <li>Embracing Interdisciplinary Skills</li>
#         <li>Researching and Choosing Opportunities Wisely</li>
#     </ul>
# <h1>Proof of me being there..</h1>
# <img width="1512" alt="image" src="https://github.com/user-attachments/assets/269ae36a-983c-4140-bc59-1c81550dd9af">
