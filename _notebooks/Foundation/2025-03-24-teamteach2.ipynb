# %% [raw]
# ---
# layout: post
# title: Digital Divide Team Teaching Blog
# description: Digital Divide Popcorn and Homework Hacks
# permalink: /digitaldivide/
# comments: true
# ---

# %% [markdown]
# # Popcorn Hack 1

# %% [markdown]
# <h3> Mcq Question: Which of the following actions are likely to be helpful in reducing the digital divide. Select two answers.
#
# Answer B and D </h3>

# %% [markdown]
# # Popcorn Hack 2

# %% [markdown]
# <h3>Making high-quality internet available to everyone for free through government provision is one of the things I would do to address the digital gap and make it less noticeable in our society.  The digital infrastructure in San Diego is already being improved, and initiatives aimed at assisting students in gaining access to the internet are underway.  We can install top-notch internet routers around the city, for example.</h3>

# %% [markdown]
# # Homework Hack

# %%
import pandas as pd

# Load and clean the dataset
data = pd.read_csv("internet_users.csv").drop(columns=['Notes', 'Year.2', 'Users (CIA)', 'Rate (ITU)', 'Year.1'])
data_cleaned = data.dropna()

# Extract required columns
y = data_cleaned['Rate (WB)']
name = data_cleaned['Location']

# Loop through the data and print results
for country, rate in zip(name, y):
    status = "doing great" if rate > 70 else "needs improvement"
    print(f"{country}: {rate}%: {status}")
# Out:
# World: 67.4%: needs improvement
# Afghanistan: 18.4%: needs improvement
# Albania: 83.1%: doing great
# Algeria: 71.2%: doing great
# Andorra: 94.5%: doing great
# Angola: 39.3%: needs improvement
# Antigua and Barbuda: 91.4%: doing great
# Argentina: 89.2%: doing great
# Armenia: 78.6%: doing great
# Aruba: 97.2%: doing great
# Australia: 95.0%: doing great
# Austria: 95.3%: doing great
# Azerbaijan: 88.0%: doing great
# Bahamas: 94.4%: doing great
# Bahrain: 100.0%: doing great
# Bangladesh: 44.5%: needs improvement
# Barbados: 76.2%: doing great
# Belarus: 91.5%: doing great
# Belgium: 94.6%: doing great
# Belize: 70.4%: doing great
# Benin: 33.8%: needs improvement
# Bermuda: 98.4%: doing great
# Bhutan: 86.8%: doing great
# Bolivia: 73.3%: doing great
# Bosnia and Herzegovina: 83.4%: doing great
# Botswana: 77.3%: doing great
# Brazil: 84.2%: doing great
# British Virgin Islands: 77.7%: doing great
# Brunei: 99.0%: doing great
# Bulgaria: 80.4%: doing great
# ...

# %% [markdown]
# # 3 sentence summary

# %% [markdown]
# <h3>I added a few comments to the code to help you understand what each part does. The code reads the data from the CSV file, cleans it, and extracts the required columns. It then loops through the data, printing the country name, internet usage rate, and a status message based on the rate. The status message is determined by checking if the rate is greater than 70%. You can adjust the threshold value as needed.</h3>
